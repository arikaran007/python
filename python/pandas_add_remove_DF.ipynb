# %% [markdown]
# <a href="https://colab.research.google.com/github/arikaran007/python/blob/main/python/pandas_add_remove_DF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
people = {
    "first": ["Corey", 'Jane', 'John'],
    "last": ["Schafer", 'Doe', 'Doe'],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df =pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['full_name']=df['first'] + ' ' +df['last']

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df.drop(columns=['first','last'])
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
df['full_name'].str.split(' ',expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[['first','last']] = df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df.append({'first':'TOny'},ignore_index=True)
# Out:
# <ipython-input-12-970aaa9b5f35>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first':'TOny'},ignore_index=True)
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe
# 3   TOny      NaN                      NaN            NaN

# %%
people = {
    "first": ["Tony", 'Stark',],
    "last": ["Captain", 'America',],
    "email": ["ironman@gmail.com", 'captain@email.com']
}

# %%
df2 = pd.DataFrame(people)
df2
# Out:
#    first     last              email
# 0   Tony  Captain  ironman@gmail.com
# 1  Stark  America  captain@email.com

# %%
df=df.append(df2,ignore_index=True)
# Out:
# <ipython-input-28-df279cc9d81f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df2,ignore_index=True)

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe
# 3   Tony  Captain        ironman@gmail.com            NaN
# 4  Stark  America        captain@email.com            NaN

# %%
df.drop(index=4)
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe
# 3   Tony  Captain        ironman@gmail.com            NaN

# %%
df.drop(index=df[df['last']=='Doe'].index)
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 3   Tony  Captain        ironman@gmail.com            NaN
# 4  Stark  America        captain@email.com            NaN

# %%
filt =df['last'] == 'Captain'
df.drop(index=df[filt].index)
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe
# 4  Stark  America        captain@email.com            NaN
